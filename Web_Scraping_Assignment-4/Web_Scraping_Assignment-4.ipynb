# %%
# !pip install selenium
# !pip install bs4
1pip install requests  #Requirement already satisfied

# %%
#Libraries
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
import requests

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException,StaleElementReferenceException

import warnings
warnings.filterwarnings ('ignore')

# %% [markdown]
# # Q. 1.  Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
# creating empty list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#Rank
rank=driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[1]')
for i in rank:
    try:
        Rank.append(i.text)
    except NoSuchElementException:
        Rank.append('-')
        

#name
name=driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[2]')
for i in name:
    try:
        Name.append(i.text)
    except NoSuchElementException:
        Name.append('-')
        
#Artist
artist=driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[3]')
for i in artist:
    try:
        Artist.append(i.text)
    except NoSuchElementException:
        Artist.append('-')
        
#Upload_date
upload_date=driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[5]')
for i in upload_date:
    try:
        Upload_date.append(i.text)
    except NoSuchElementException:
        Upload_date.append('-')
        
        
#Views
views=driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[4]')
for i in views:
    try:
        Views.append(i.text)
    except NoSuchElementException:
        Views.append('-')

# %%
youtubedata=pd.DataFrame({"Rank":Rank,"Name":Name,"Artist":Artist,"Upload_date":Upload_date, "Views in billions":Views})
youtubedata
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                     "Axel F"[35]
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#Libraries
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
import requests

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException,StaleElementReferenceException

import warnings
warnings.filterwarnings ('ignore')

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.bcci.tv/')

# %%
#click on international automated
international=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
#creating emptylist for asked data
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
#scraping required data by xpath for the data we have made empty list above

#match title
match_title=driver.find_elements(By.XPATH,'//*[@id="fixtures"]/div[3]/div//div/span[1]')
for i in match_title:
    try:
        Match_title.append(i.text)
    except NoSuchElementException:
        Match_title.append('-')
        
#series
series=driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
for i in series:
    try:
        Series.append(i.text)
    except NoSuchElementException:
        Series.append('-')

#place
place=driver.find_elements(By.XPATH,'//*[@id="fixtures"]/div[3]/div//div/span[2]')
for i in place:
    try:
        Place.append(i.text)
    except NoSuchElementException:
        Place.append('-')

#date
date=driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
for i in date:
    try:
        Date.append(i.text)
    except NoSuchElementException:
        Date.append('-')
        
        
#time
time=driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in time:
    try:
        Time.append(i.text)
    except NoSuchElementException:
        Time.append('-')

# %%
len(Match_title),len(Series),len(Place),len(Date),len(Time)
# Out:
# (3, 3, 3, 3, 3)

# %%
OdiData=pd.DataFrame({"Match_title":Match_title,
                      "Series":Series,
                      "Place":Place,
                      "Date":Date,
                      "Time":Time})
OdiData
# Out:
#   Match_title                        Series  \
# 0   1st ODI -  AUSTRALIA TOUR OF INDIA 2023
# 1   2nd ODI -  AUSTRALIA TOUR OF INDIA 2023
# 2   3rd ODI -  AUSTRALIA TOUR OF INDIA 2023
#
#                                                Place         Date         Time
# 0                                  Wankhede Stadium,  17 MAR 2023  1:30 PM IST
# 1  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,  19 MAR 2023  1:30 PM IST
# 2                            MA Chidambaram Stadium,  22 MAR 2023  1:30 PM IST

# %%
driver.close()

# %% [markdown]
# # Q. 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#Libraries
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
import requests

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException,StaleElementReferenceException

import warnings
warnings.filterwarnings ('ignore')

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.statisticstimes.com/')

# %%
#click on economy dropdown button then india automated
eco_dopdwn=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

india=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').click()

# %%
#click on gdp of indian states automated
gdp_india_state=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
#creating emptylist for asked data
Rank=[]
State=[]
GSDP1819=[]                     #GSDP(18-19)- at current prices
GSDP1920=[]                     #GSDP(19-20)- at current prices
Share=[]                        #Share(18-19)
GDP=[]                          #GDP($ billion)

# %%
#scraping required data by xpath for the data we have made empty list above

#rank
rank=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[1]')
for i in rank:
    try:
        Rank.append(i.text)
    except NoSuchElementException:
        Rank.append('-')


#state
state=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[2]')
for i in state:
    try:
        State.append(i.text)
    except NoSuchElementException:
        State.append('-')


#GSDP(18-19)- at current prices
gsdp18=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[4]')
for i in gsdp18:
    try:
        GSDP1819.append(i.text)
    except NoSuchElementException:
        GSDP1819.append('-')

#GSDP(19-20)- at current prices
gsdp19=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[3]')
for i in gsdp19:
    try:
        GSDP1920.append(i.text)
    except NoSuchElementException:
        GSDP1920.append('-') 

#Share(18-19)
share=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[5]')
for i in share:
    try:
        Share.append(i.text)
    except NoSuchElementException:
        Share.append('-') 

#GDP($ billion)
gdp=driver.find_elements(By.XPATH,'//*[@id="table_id"]/tbody/tr/td[6]')
for i in gdp:
    try:
        GDP.append(i.text)
    except NoSuchElementException:
        GDP.append('-')

# %%
len(Rank), len(State), len(GSDP1819), len(GSDP1920), len(Share), len(GDP)
# Out:
# (33, 33, 33, 33, 33, 33)

# %%
#data frame & coumns are in order as asked in question

gdp_df=pd.DataFrame({"Rank":Rank, "State":State, 
                     "GSDP(18-19)- at current prices": GSDP1819 , 
                     "GSDP(19-20)- at current prices": GSDP1920, 
                     "Share":Share, "GDP":GDP })
gdp_df
# Out:
#    Rank                      State GSDP(18-19)- at current prices  \
# 0     1                Maharashtra                      2,632,792
# 1     2                 Tamil Nadu                      1,630,208
# 2     3              Uttar Pradesh                      1,584,764
# 3     4                    Gujarat                      1,502,899
# 4     5                  Karnataka                      1,493,127
# 5     6                West Bengal                      1,089,898
# 6     7                  Rajasthan                        942,586
# 7     8             Andhra Pradesh                        862,957
# 8     9                  Telangana                        861,031
# 9    10             Madhya Pradesh                        809,592
# 10   11                     Kerala                        781,653
# 11   12                      Delhi                        774,870
# 12   13                    Haryana                        734,163
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
#Libraries
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
import requests

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException,StaleElementReferenceException

import warnings
warnings.filterwarnings ('ignore')

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://github.com/')

# %%
#click on open_source button then trending automated
open_source=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
open_source.click()

trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
trending.click()

# %%
#Creating empty list:
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

#Fetching urls for each repository
repository = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

# %%
# Scraping Repository Title data
title = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

# %%
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(2)
    
        # Scraping Repository Description data
    try:
        desc = driver.find_element(By.XPATH,"//p[@class='f4 my-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # Scraping Contributors Count data
    try:
        contributor = driver.find_element(By.XPATH,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
        
     # Scraping Languages used data
    lang=[]
    try:
        for i in driver.find_elements(By.XPATH,'//span[@class="color-fg-default text-bold mr-1"]'):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        lang.append('-')

# %%
print(len(repository_title),len(Description),len(Contributors),len(Language))
# Out:
# 25 25 25 25

# %%
#Data Frame

Github=pd.DataFrame({'Repository title':repository_title,
                    'Repository description':Description,
                    'Contributors count':Contributors,
                    'Language used':Language})

Github
# Out:
#                              Repository title  \
# 0           dreamworksanimation / openmoonray
# 1                    comfyanonymous / ComfyUI
# 2                      logspace-ai / langflow
# 3                         setzer22 / llama-rs
# 4                 ayaka14732 / ChatGPTAPIFree
# 5                whoiskatrin / sql-translator
# 6                         acheong08 / EdgeGPT
# 7                  apache / incubator-opendal
# 8                         tloen / alpaca-lora
# 9                          THUDM / ChatGLM-6B
# 10                             xx025 / carrot
# 11                    brunosimon / folio-2019
# 12                          microsoft / unilm
# 13  massgravel / Microsoft-Activation-Scripts
# 14                              lapce / lapce
# 15                   openai / openai-cookbook
# 16                         karpathy / nanoGPT
# 17                             openai / evals
# 18                      WassimTenachi / PhySO
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 5. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.billboard.com/')

# %%
##click on chart automated
chart=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
chart.click()

# %%
#click on top100 automated
top100=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a')
top100.click()

# %%
#  scraping by xpath
Rank=[]
rank=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet"]')
for i in rank:
    try:
        Rank.append(i.text.strip(" ").strip("\n"))
    except NoSuchElementException:
        Rank.append('-')

# %%
# Song name scraping by xpath
Song=[]
song=driver.find_elements(By.XPATH,'//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]')
for i in song:
    try:
        Song.append(i.text.split("\n")[0])
    except NoSuchElementException:
        Song.append('-')

# %%
# Artist name scraping by xpath
Artist=[]
artist=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]//ul/li[1]/span')
for i in artist:
    try:
        Artist.append(i.text)
    except NoSuchElementException:
        Artist.append('-')

# %%
# Last week rank scraping by xpath
LastWRank=[]
lastwRank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"][1]')
for i in lastwRank:
    try:
        LastWRank.append(i.text)
    except NoSuchElementException:
        LastWRank.append('-')

# %%
# Peak rank scraping by xpath
P_rank=[]
p_rank=driver.find_elements(By.XPATH,'//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[5]')
for i in p_rank:
    try:
        P_rank.append(i.text)
    except NoSuchElementException:
        P_rank.append('-')

# %%
# Weeks on board scraping by xpath
WOB=[]
wob=driver.find_elements(By.XPATH,'//*[@id="post-1479786"]/div[3]/div/div/div/div[2]//ul/li[4]/ul/li[6]')
for i in wob:
    try:
        WOB.append(i.text)
    except NoSuchElementException:
        WOB.append('-')

# %%
len(Rank),len(Song), len(Artist), len(LastWRank), len(P_rank), len(WOB)
# Out:
# (100, 100, 100, 100, 100, 100)

# %%
topsong_data=pd.DataFrame({"Rank":Rank,"Song name":Song, "Artist name":Artist, "Last week rank":LastWRank, "Peak rank":P_rank, 
                           "Weeks on board":WOB})
topsong_data
# Out:
#    Rank            Song name                                     Artist name  \
# 0     1           Last Night                                   Morgan Wallen
# 1     2              Flowers                                     Miley Cyrus
# 2     3            Kill Bill                                             SZA
# 3     4          Die For You                      The Weeknd & Ariana Grande
# 4     5  Boy's A Liar, Pt. 2                      PinkPantheress & Ice Spice
# ..  ...                  ...                                             ...
# 95   96             Nonsense                               Sabrina Carpenter
# 96   97                  AMG  Gabito Ballesteros, Peso Pluma & Natanael Cano
# 97   98           Lift Me Up                                         Rihanna
# 98   99           You Didn't                                     Brett Young
# 99  100                10:35                     Tiesto Featuring Tate McRae
#
#    Last week rank Peak rank Weeks on board
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 6. Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
#title
title=[]
try:
    tags=driver.find_elements(By.XPATH,"//td[2][@class='left']")
    for i in tags:
        title.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    title.append("-")

# %%
#author
author=[]
try:
    tags=driver.find_elements(By.XPATH,"//td[3][@class='left']")
    for i in tags:
        author.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    author.append("-")

# %%
#Volumes sold
sold=[]
try:
    tags=driver.find_elements(By.XPATH,"//td[4][@class='left']")
    for i in tags:
        sold.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    sold.append("-")

# %%
#Publisher
publisher=[]
try:
    tag=driver.find_elements(By.XPATH,"//td[5][@class='left']")
    for i in tag:
        publisher.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    publisher.append("-")

# %%
#genre
genre=[]
try:
    tag=driver.find_elements(By.XPATH,"//td[@class='last left']")
    for i in tag:
        genre.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    genre.append("-")

# %%
noveldf=pd.DataFrame({"Book_Name":title,
                      "Author":author,
                      "Volumes_sold":sold,
                      "Publisher":publisher
                      ,"Genre":genre})
noveldf
# Out:
#                                             Book_Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
#Name
name=[]
try:
    tags=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
    for i in tags:
        name.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    name.append("-")

# %%
#Year span
year=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
    for i in tags:
        year.append(i.text.replace("\n"," ").strip("()"))
except Exception:
    year.append("-")

# %%
#genre
genre=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in tags:
        genre.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    genre.append("-")

# %%
#Run time
time=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in tags:
        time.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    time.append("-")

# %%
#rating
rating=[]
try:
    tags=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']")
    for i in tags:
        rating.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    rating.append("-")

# %%
#votes
votes=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in tags:
        votes.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    votes.append("-")

# %%
imdb100df=pd.DataFrame({"Movie Name":name,"Year Span":year,"Genre":genre,"Runtime":time,"Ratings":rating,"Votes":votes})
imdb100df
# Out:
#                         Movie Name  Year Span                     Genre  \
# 0                  Game of Thrones  2011–2019  Action, Adventure, Drama
# 1                  Stranger Things  2016–2024    Drama, Fantasy, Horror
# 2                 The Walking Dead  2010–2022   Drama, Horror, Thriller
# 3                   13 Reasons Why  2017–2020  Drama, Mystery, Thriller
# 4                          The 100  2014–2020    Drama, Mystery, Sci-Fi
# ..                             ...        ...                       ...
# 95                           Reign  2013–2017                     Drama
# 96  A Series of Unfortunate Events  2017–2019  Adventure, Comedy, Drama
# 97                  Criminal Minds     2005–      Crime, Drama, Mystery
# 98           Scream: The TV Series  2015–2019      Comedy, Crime, Drama
# 99      The Haunting of Hill House       2018    Drama, Horror, Mystery
#
#     Runtime Ratings      Votes
# 0    57 min     9.2  2,138,426
# 1    51 min     8.7  1,223,317
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 8. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://archive.ics.uci.edu/')

# %%
all_sets=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
all_sets.click()

# %%
#data_type
data_type=[]
try:
    info=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
        data_type.append(i.text)
except NoSuchElementException:
    data_type.append("-")

# %%
#Name
name=[]
try:
    tags=driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
    for i in tags:
        name.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    name.append("-")

# %%
#Task
Task=[]
try:
    tags=driver.find_elements(By.XPATH,"//tbody//tr//td[3]//p")
    for i in tags:
        Task.append(i.text.replace("\n"," ").strip("Default Task"))
except Exception:
    Task.append("-")
Task.pop(0)
Task.pop()
len(Task)
# Out:
# 622

# %%
#Attribute type
atype=[]
try:
    tags=driver.find_elements(By.XPATH,"//tr//td[4]//p")
    for i in tags:
        atype.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    atype.append("-")
atype.pop(0)
# Out:
# 'Attribute Types'

# %%
#No of instances
instance=[]
try:
    tags=driver.find_elements(By.XPATH,"//tr//td[5]//p")
    for i in tags:
        instance.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    instance.append("-")
instance.pop(0)
# Out:
# '# Instances'

# %%
#No of attribute
attribut=[]
try:
    tags=driver.find_elements(By.XPATH,"//tr//td[6]//p")
    for i in tags:
        attribut.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    attribut.append("-")
attribut.pop(0)
# Out:
# '# Attributes'

# %%
#year
year=[]
try:
    tags=driver.find_elements(By.XPATH,"//tr//td[7]//p")
    for i in tags:
        year.append(i.text.replace("\n"," ").strip(" "))
except Exception:
    year.append("-")
year.pop(0)
# Out:
# 'Year'

# %%
len(name),len(atype),len(Task),len(year),len(attribut),len(instance),len(data_type)
# Out:
# (622, 622, 622, 622, 622, 622, 622)

# %%
UCIdf=pd.DataFrame({"Name":name,"Data Type":data_type,"Attribute_Type":atype,"Task":Task,"Attributes":attribut,"Instances":instance,"Year":year})
UCIdf
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type              Attribute_Type  \
# 0                 Multivariate   Categorical, Integer, Real
# 1                 Multivariate         Categorical, Integer
# 2                 Multivariate   Categorical, Integer, Real
# ...

# %%
driver.close()

# %% [markdown]
# # Q. 9. Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C)Company
# D)Skills they hire for
# E) Location

# %%
# connecting to driver & opening required page on automated chrome browser
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
driver.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
##click on recruiters automated
recruiters=driver.find_element(By.XPATH,"/html/body/div[1]/div/ul/li[2]/a/div")
recruiters.click()

# %%
#searching automated
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input")
search.send_keys("Data Science")

button=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
button.click()

# %%
#Name
name=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
    for i in tags:
        name.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    name.append("-")

# %%
#Designation
designation=[]
try:
    tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
    for i in tags:
        designation.append(i.text.replace("\n"," ").strip(" "))
except NoSuchElementException:
    designation.append("-")

# %%
#Company
comp=[]
try:
    tag=driver.find_elements(By.XPATH,"//a[2][@class='ellipsis']")
    for i in tag:
        comp.append(i.text)
except NoSuchElementException:
    comp.append("-")

# %%
#Skills they hire for
skills=[]
try:
    tag=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
    for i in tag:
        skills.append(i.text.replace("\n"," "))
except NoSuchElementException:
    skills.append("-")

# %%
#Location
loc=[]
try:
    tag=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
    for i in tag:
        loc.append(i.text.replace("\n"," ").strip(" "))
    else:
        loc.append("-")
except NoSuchElementException:
    loc.append("-")

# %%
len(name),len(designation),len(comp),len(skills),len(loc)
# Out:
# (50, 50, 50, 50, 50)

# %%
naukridf=pd.DataFrame({"Name":name,"Designation":designation,"Company":comp,"Skills they hire for":skills,"Location":loc})
naukridf
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()
